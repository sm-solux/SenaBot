118 111 107 108 123 131 143 154 158 166 177 181 175 170 159 148 171 161 176 185 192 194 188 190 162 53 49 58 63 61 61 55 56 61 51 50 81 116 139 142 142 146 144 136 128 119 112 97 85 90 91 88 92 90 80 81 84 106 122 132 144 145 144 147 163 147 163 173 181 190 187 191 167 61 48 53 61 61 58 54 56 61 51 53 89 123 140 144 145 146 147 136 122 107 99 95 92 90 87 83 76 67 52 46 52 63 69 83 96 119 132 148 159 136 137 143 138 143 152 156 156 70 48 50 59 61 57 54 54 61 52 56 93 124 135 140 144 148 150 140 125 114 101 80 54 56 54 41 41 33 40 39 35 49 60 63 74 107 129 147 147 116 111 100 77 76 86 108 111 73 49 50 60 62 60 57 55 63 59 56 89 121 134 139 146 151 152 150 141 127 111 96 77 85 70 32 31 37 91 65 50 48 59 73 83 112 136 155 130 60 46 38 40 43 81 116 91 72 52 48 58 62 62 59 53 61 59 52 85 114 134 140 147 154 159 158 153 145 143 150 126 121 125 68 45 89 137 95 70 78 75 95 109 131 153 171 94 23 16 32 82 82 65 113 77 71 54 48 56 62 62 60 53 60 56 52 75 108 133 141 149 158 166 169 167 163 156 155 146 112 119 134 127 142 140 121 117 129 114 120 129 146 174 191 98 46 33 33 109 147 98 109 67 73 55 50 56 64 64 61 58 61 53 54 64 106 129 140 148 159 169 175 176 174 165 159 156 145 120 115 124 127 131 133 141 147 142 141 147 161 182 202 154 114 96 100 158 158 153 123 61 76 57 48 56 64 64 63 62 61 54 55 44 97 131 137 147 158 168 177 181 183 179 170 168 169 165 155 152 151 152 154 162 165 158 153 158 168 187 206 186 147 135 144 145 152 178 115 57 74 58 48 58 64 63 63 59 63 55 53 66 104 130 132 144 153 162 170 180 185 187 181 178 182 180 177 173 171 171 177 176 172 164 161 167 164 185 207 197 173 152 141 141 161 191 104 54 69 60 48 57 65 62 60 57 64 55 50 94 111 124 130 135 150 15 ...

# %%
len(data[' pixels'][0])
# Out:
# 8287

# %% [markdown]
# ### 공백으로 구분된 데이터를 넘파이로 변경

# %%
temp = np.fromstring(data[' pixels'][0], dtype=int, sep=' ')
print(len(temp))
# Out:
# 2304

# %% [markdown]
# ### 모델에 입력으로 넣기 위한 데이터 전처리 함수

# %%
# 데이터 전처리 함수
def preprocessing(data):
    image = np.zeros(shape=(len(data), 48, 48))  # (48*48)
    label = np.array(list(map(int, data['emotion'])))
    
    for i,row in enumerate(data.index):
        df = np.fromstring(data[' pixels'][row], dtype=int, sep=' ')
        df = np.reshape(df, (48, 48))
        image[i] = df
    return image, label

# %%
# Train, Validation, Test 데이터 구분
x_train, y_train = preprocessing(data[data[' Usage'] == 'Training'])
x_val, y_val = preprocessing(data[data[' Usage'] == 'PrivateTest'])
x_test, y_test = preprocessing(data[data[' Usage']=='PublicTest'])

# %%
print(x_train.shape)
print(x_val.shape)
print(x_test.shape)
# Out:
# (28709, 48, 48)
# (3589, 48, 48)
# (3589, 48, 48)

# %% [markdown]
# ### 이미지 확인

# %%
plt.imshow(x_train[0], cmap='gray')
print("lable: ", y_train[0])
# Out:
# lable:  0

# %%
plt.imshow(x_train[100], cmap='gray')
print("lable: ", y_train[100])
# Out:
# lable:  3

# %% [markdown]
# ### 베이스라인 모델

# %%
# 모델1
model = Sequential([
    Flatten(input_shape=(48, 48)),
    Dense(128, activation='relu'),
    Dense(7, activation='softmax')
])

# 모델 컴파일
model.compile(optimizer='adam',
             loss='sparse_categorical_crossentropy',
             metrics=['accuracy'])

# 훈련(학습)
history = model.fit(x_train, y_train, validation_data=(x_val, y_val), epochs=5, batch_size=64)
# Out:
# Epoch 1/5
# 449/449 [==============================] - 3s 5ms/step - loss: 37.0376 - accuracy: 0.2153 - val_loss: 15.2896 - val_accuracy: 0.2577
# Epoch 2/5
# 449/449 [==============================] - 2s 5ms/step - loss: 11.0360 - accuracy: 0.2374 - val_loss: 7.5876 - val_accuracy: 0.2327
# Epoch 3/5
# 449/449 [==============================] - 2s 5ms/step - loss: 1.9441 - accuracy: 0.2177 - val_loss: 1.8656 - val_accuracy: 0.2460
# Epoch 4/5
# 449/449 [==============================] - 2s 4ms/step - loss: 1.8483 - accuracy: 0.2517 - val_loss: 1.8382 - val_accuracy: 0.2460
# Epoch 5/5
# 449/449 [==============================] - 2s 5ms/step - loss: 1.8281 - accuracy: 0.2516 - val_loss: 1.8261 - val_accuracy: 0.2458

# %%
# 모델2
model = Sequential([
    Flatten(input_shape=(48, 48)),
    BatchNormalization(),
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dense(7, activation='softmax')
])

# 모델 컴파일
model.compile(optimizer='adam',
             loss='sparse_categorical_crossentropy',
             metrics=['accuracy'])

# 훈련(학습)
history = model.fit(x_train, y_train, validation_data=(x_val, y_val), epochs=5, batch_size=64)
# Out:
# Epoch 1/5
# 449/449 [==============================] - 4s 7ms/step - loss: 1.7098 - accuracy: 0.3406 - val_loss: 1.6549 - val_accuracy: 0.3639
# Epoch 2/5
# 449/449 [==============================] - 4s 8ms/step - loss: 1.5756 - accuracy: 0.3885 - val_loss: 1.5923 - val_accuracy: 0.3778
# Epoch 3/5
# 449/449 [==============================] - 3s 7ms/step - loss: 1.5260 - accuracy: 0.4100 - val_loss: 1.5571 - val_accuracy: 0.4012
# Epoch 4/5
# 449/449 [==============================] - 3s 8ms/step - loss: 1.4813 - accuracy: 0.4300 - val_loss: 1.5677 - val_accuracy: 0.3890
# Epoch 5/5
# 449/449 [==============================] - 3s 7ms/step - loss: 1.4443 - accuracy: 0.4448 - val_loss: 1.5357 - val_accuracy: 0.4062

# %%
loss, acc = model.evaluate(x_test, y_test)
print('test정확도: ', acc)
# Out:
# 113/113 [==============================] - 0s 2ms/step - loss: 1.5491 - accuracy: 0.4068
# test정확도:  0.4067985415458679

# %% [markdown]
# ### CNN으로

# %%
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.callbacks import EarlyStopping

# %%
# shape 변경
print(x_train.shape, x_val.shape, x_test.shape)
x_train = x_train.reshape((x_train.shape[0], 48, 48, 1))
x_val = x_val.reshape((x_val.shape[0], 48, 48, 1))
x_test = x_test.reshape((x_test.shape[0], 48, 48, 1))
print(x_train.shape, x_val.shape, x_test.shape)

# 0 ~ 1 사이로 변경
x_train = x_train.astype('float32')/x_train.max()
x_val = x_val.astype('float32')/x_val.max()
x_test = x_test.astype('float32')/x_test.max()
# Out:
# (28709, 48, 48) (3589, 48, 48) (3589, 48, 48)
# (28709, 48, 48, 1) (3589, 48, 48, 1) (3589, 48, 48, 1)

# %%
# 모델3
model = Sequential([
    Conv2D(64, (3, 3), activation='relu', input_shape=(48, 48, 1)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(128, activation='relu'),
    Dense(7, activation='softmax')
])

# 모델 컴파일
model.compile(optimizer='adam',
             loss='sparse_categorical_crossentropy',
             metrics=['accuracy'])

early_stopping = EarlyStopping(monitor='val_accuracy', patience=3)

# 훈련(학습)
history = model.fit(x_train, y_train, validation_data=(x_val, y_val), epochs=30, batch_size=64, callbacks=[early_stopping])
# Out:
# Epoch 1/30
# 449/449 [==============================] - 93s 205ms/step - loss: 1.6219 - accuracy: 0.3623 - val_loss: 1.4800 - val_accuracy: 0.4322
# Epoch 2/30
# 449/449 [==============================] - 99s 221ms/step - loss: 1.4042 - accuracy: 0.4593 - val_loss: 1.3642 - val_accuracy: 0.4698
# Epoch 3/30
# 449/449 [==============================] - 83s 185ms/step - loss: 1.3034 - accuracy: 0.5013 - val_loss: 1.3186 - val_accuracy: 0.4943
# Epoch 4/30
# 449/449 [==============================] - 78s 173ms/step - loss: 1.2223 - accuracy: 0.5346 - val_loss: 1.2943 - val_accuracy: 0.4948
# Epoch 5/30
# 449/449 [==============================] - 84s 187ms/step - loss: 1.1391 - accuracy: 0.5700 - val_loss: 1.2405 - val_accuracy: 0.5344
# Epoch 6/30
# 449/449 [==============================] - 81s 180ms/step - loss: 1.0589 - accuracy: 0.6020 - val_loss: 1.2453 - val_accuracy: 0.5266
# Epoch 7/30
# 449/449 [==============================] - 80s 179ms/step - loss: 0.9747 - accuracy: 0.6370 - val_loss: 1.2514 - val_accuracy: 0.5291
# Epoch 8/30
# 449/449 [==============================] - 79s 176ms/step - loss: 0.8953 - accuracy: 0.6687 - val_loss: 1.2813 - val_accuracy: 0.5433
# Epoch 9/30
# 449/449 [==============================] - 79s 176ms/step - loss: 0.8159 - accuracy: 0.7013 - val_loss: 1.3180 - val_accuracy: 0.5350
# Epoch 10/30
# 449/449 [==============================] - 81s 182ms/step - loss: 0.7291 - accuracy: 0.7360 - val_loss: 1.3674 - val_accuracy: 0.5528
# Epoch 11/30
# 449/449 [==============================] - 87s 195ms/step - loss: 0.6490 - accuracy: 0.7672 - val_loss: 1.4397 - val_accuracy: 0.5389
# Epoch 12/30
# 449/449 [==============================] - 89s 198ms/step - loss: 0.5757 - accuracy: 0.7960 - val_loss: 1.5669 - val_accuracy: 0.5400
# Epoch 13/30
# 449/449 [==============================] - 81s 180ms/step - loss: 0.4962 - accuracy: 0.8237 - val_loss: 1.6718 - val_accuracy: 0.5241

# %%
loss, acc = model.evaluate(x_test, y_test)
print('test정확도: ', acc)
# Out:
# 113/113 [==============================] - 3s 24ms/step - loss: 1.6480 - accuracy: 0.5327
# test정확도:  0.5327389240264893

# %%
emotions = ['Angry', 'Disgust', 'Fear', 'Happy', 'Sad', 'Surprise', 'Neutral']

# %%
train['pixels'] = [np.fromstring(x, dtype=int, sep=' ').reshape(-1,48,48) for x in train['pixels']]
pixels = np.concatenate(train['pixels'])
labels = train.emotion.values

# %%
plt.rcParams["figure.figsize"] = [16,16]

row = 0
for i in np.unique(labels):
    all_emotion_images = train[train['emotion'] == i]
    
    for j in range(5):
        img = all_emotion_images.iloc[j,].pixels.reshape(48,48)
        lab = emotions[i]

        plt.subplot(7,5,row+j+1)
        plt.imshow(img, cmap='binary_r')
        plt.text(-30, 5, s = str(lab), fontsize=10, color='b')
        plt.axis('off')
    row += 5

plt.show()

# %%
from PIL import Image

img = np.array(Image.open("./image/marathon_03.jpg"))
img_string = ' '.join(map(str, img.flatten().tolist()))

# %%
plt.imshow(img, cmap='gray')
print("lable: ")
# Out:
# lable:
